# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from sklearn.metrics import (confusion_matrix, classification_report,
                             roc_auc_score, roc_curve, auc)
from sklearn.preprocessing import label_binarize
from itertools import cycle
#  from scipy import interp

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score
import numpy as np

# %%
# Load preprocessed features
df_tfidf = pd.read_pickle('/content/drive/My Drive/Colab/AS4/STEP2-feature_Engineering/features_tfidf.pkl')
df_bow = pd.read_pickle('/content/drive/My Drive/Colab/AS4/STEP2-feature_Engineering/features_bow.pkl')
df_ngram = pd.read_pickle('/content/drive/My Drive/Colab/AS4/STEP2-feature_Engineering/features_ngram2.pkl')
df_lda = pd.read_pickle('/content/drive/My Drive/Colab/AS4/STEP2-feature_Engineering/features_lda.pkl')

# Prepare data
labels = df_tfidf['label']
numeric_labels = df_tfidf['label_num'].values
classes = np.unique(numeric_labels)
from sklearn.preprocessing import label_binarize
y_binarized = label_binarize(numeric_labels, classes=classes)

# Feature matrices (drop label columns)
X_tfidf = df_tfidf.drop(['label', 'label_num'], axis=1).values
X_bow = df_bow.drop(['label', 'label_num'], axis=1).values
X_ngram = df_ngram.drop(['label', 'label_num'], axis=1).values
X_lda = df_lda.drop(['label', 'label_num'], axis=1).values

# Combine features function
def combine_features(*arrays):
    return np.hstack(arrays)

# Dictionary of feature sets (include individual and combinations)
feature_sets = {
    'TF-IDF': X_tfidf,
    'BoW': X_bow,
    'N-grams': X_ngram,
    'LDA': X_lda,
    'TF-IDF + BoW': combine_features(X_tfidf, X_bow),
    'TF-IDF + N-grams': combine_features(X_tfidf, X_ngram),
    'TF-IDF + LDA': combine_features(X_tfidf, X_lda),
    'BoW + N-grams': combine_features(X_bow, X_ngram),
    'BoW + LDA': combine_features(X_bow, X_lda),
    'N-grams + LDA': combine_features(X_ngram, X_lda),
    'TF-IDF + BoW + N-grams': combine_features(X_tfidf, X_bow, X_ngram),
    'TF-IDF + BoW + LDA': combine_features(X_tfidf, X_bow, X_lda),
    'TF-IDF + N-grams + LDA': combine_features(X_tfidf, X_ngram, X_lda),
    'BoW + N-grams + LDA': combine_features(X_bow, X_ngram, X_lda),
    'All Combined': combine_features(X_tfidf, X_bow, X_ngram, X_lda),
}
y = labels

# %%
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
results = {}

for name, X in feature_sets.items():
    accuracies = []
    roc_aucs = []

    print(f"\nTraining and evaluating with feature set: {name}")
    for fold, (train_index, test_index) in enumerate(kf.split(X, numeric_labels), 1):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = numeric_labels[train_index], numeric_labels[test_index]
        y_test_binarized = y_binarized[test_index]

        params = {'alpha': 0.0001, 'eta0': 0.1, 'learning_rate': 'constant', 'loss': 'log_loss', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.0001}

        ngr_sgd = SGDClassifier(**params)
        ngr_sgd.fit(X_train, y_train)

        y_pred = ngr_sgd.predict(X_test)
        y_proba = ngr_sgd.predict_proba(X_test)

        acc = accuracy_score(y_test, y_pred)

        # Handle binary/multiclass ROC-AUC
        if len(np.unique(numeric_labels)) == 2:
            roc_auc = roc_auc_score(y_test, y_proba[:, 1])
        else:
            roc_auc = roc_auc_score(y_test_binarized, y_proba, multi_class='ovr')

        accuracies.append(acc)
        roc_aucs.append(roc_auc)

        print(f"  Fold {fold}: Accuracy = {acc:.4f}, ROC-AUC = {roc_auc:.4f}")

    avg_acc = np.mean(accuracies)
    avg_roc = np.mean(roc_aucs)
    results[name] = (avg_acc, avg_roc)

    print(f"Average Accuracy: {avg_acc:.4f}, Average ROC-AUC: {avg_roc:.4f}\n")

# Summary Table
print("\nSummary of Results:")
print(f"{'Feature Set':<30} {'Accuracy':<10} {'ROC-AUC':<10}")
for key, (acc, roc) in results.items():
    print(f"{key:<30} {acc:<10.4f} {roc:<10.4f}")

# Best Feature Set
best_feature_set = max(results.items(), key=lambda x: x[1][0])
best_name, (best_acc, best_roc) = best_feature_set

print("\n=== Best Feature Set ===")
print(f"Feature Set: {best_name}")
print(f"Accuracy: {best_acc:.4f}")
print(f"ROC-AUC: {best_roc:.4f}")
# Out:
# Training and evaluating with feature set: TF-IDF
#   Fold 1: Accuracy = 0.8800, ROC-AUC = 0.9840
#   Fold 2: Accuracy = 0.9300, ROC-AUC = 0.9938
#   Fold 3: Accuracy = 0.9800, ROC-AUC = 0.9982
#   Fold 4: Accuracy = 0.9500, ROC-AUC = 0.9960
#   Fold 5: Accuracy = 0.9400, ROC-AUC = 0.9974
#   Fold 6: Accuracy = 0.9100, ROC-AUC = 0.9950
#   Fold 7: Accuracy = 0.9200, ROC-AUC = 0.9955
#   Fold 8: Accuracy = 0.9200, ROC-AUC = 0.9938
#   Fold 9: Accuracy = 0.9200, ROC-AUC = 0.9963
#   Fold 10: Accuracy = 0.9400, ROC-AUC = 0.9918
# Average Accuracy: 0.9290, Average ROC-AUC: 0.9942
#
#
# Training and evaluating with feature set: BoW
#   Fold 1: Accuracy = 0.8900, ROC-AUC = 0.9796
#   Fold 2: Accuracy = 0.9100, ROC-AUC = 0.9909
#   Fold 3: Accuracy = 0.9800, ROC-AUC = 0.9948
#   Fold 4: Accuracy = 0.9500, ROC-AUC = 0.9957
#   Fold 5: Accuracy = 0.9600, ROC-AUC = 0.9926
#   Fold 6: Accuracy = 0.9200, ROC-AUC = 0.9934
#   Fold 7: Accuracy = 0.9300, ROC-AUC = 0.9966
#   Fold 8: Accuracy = 0.8700, ROC-AUC = 0.9904
#   Fold 9: Accuracy = 0.8900, ROC-AUC = 0.9892
#   Fold 10: Accuracy = 0.9100, ROC-AUC = 0.9790
# Average Accuracy: 0.9210, Average ROC-AUC: 0.9902
#
#
# Training and evaluating with feature set: N-grams
#   Fold 1: Accuracy = 0.9100, ROC-AUC = 0.9845
#   Fold 2: Accuracy = 0.8800, ROC-AUC = 0.9780
#   Fold 3: Accuracy = 0.9400, ROC-AUC = 0.9966
#   Fold 4: Accuracy = 0.9200, ROC-AUC = 0.9817
#   Fold 5: Accuracy = 0.8700, ROC-AUC = 0.9901
#   Fold 6: Accuracy = 0.9100, ROC-AUC = 0.9905
#   Fold 7: Accuracy = 0.8700, ROC-AUC = 0.9774
#   Fold 8: Accuracy = 0.8900, ROC-AUC = 0.9841
#   Fold 9: Accuracy = 0.8600, ROC-AUC = 0.9801
#   Fold 10: Accuracy = 0.8700, ROC-AUC = 0.9754
# Average Accuracy: 0.8920, Average ROC-AUC: 0.9839
#
#
# Training and evaluating with feature set: LDA
#   Fold 1: Accuracy = 0.4200, ROC-AUC = 0.7672
#   Fold 2: Accuracy = 0.4500, ROC-AUC = 0.7238
#   Fold 3: Accuracy = 0.3800, ROC-AUC = 0.7277
#   Fold 4: Accuracy = 0.4000, ROC-AUC = 0.7185
#   Fold 5: Accuracy = 0.4900, ROC-AUC = 0.7579
#   Fold 6: Accuracy = 0.3900, ROC-AUC = 0.7502
#   Fold 7: Accuracy = 0.5000, ROC-AUC = 0.7885
#   Fold 8: Accuracy = 0.4200, ROC-AUC = 0.7474
#   Fold 9: Accuracy = 0.4100, ROC-AUC = 0.7316
#   Fold 10: Accuracy = 0.3800, ROC-AUC = 0.6919
# Average Accuracy: 0.4240, Average ROC-AUC: 0.7405
#
#
# Training and evaluating with feature set: TF-IDF + BoW
#   Fold 1: Accuracy = 0.8700, ROC-AUC = 0.9796
#   Fold 2: Accuracy = 0.9100, ROC-AUC = 0.9926
#   Fold 3: Accuracy = 0.9600, ROC-AUC = 0.9975
#   Fold 4: Accuracy = 0.9600, ROC-AUC = 0.9953
#   Fold 5: Accuracy = 0.9500, ROC-AUC = 0.9897
#   Fold 6: Accuracy = 0.9100, ROC-AUC = 0.9930
#   Fold 7: Accuracy = 0.9200, ROC-AUC = 0.9959
#   Fold 8: Accuracy = 0.9200, ROC-AUC = 0.9926
#   Fold 9: Accuracy = 0.9100, ROC-AUC = 0.9922
#   Fold 10: Accuracy = 0.9200, ROC-AUC = 0.9799
# Average Accuracy: 0.9230, Average ROC-AUC: 0.9908
#
#
# Training and evaluating with feature set: TF-IDF + N-grams
#   Fold 1: Accuracy = 0.8900, ROC-AUC = 0.9844
#   Fold 2: Accuracy = 0.8700, ROC-AUC = 0.9741
#   Fold 3: Accuracy = 0.9100, ROC-AUC = 0.9965
#   Fold 4: Accuracy = 0.9200, ROC-AUC = 0.9814
#   Fold 5: Accuracy = 0.9000, ROC-AUC = 0.9901
#   Fold 6: Accuracy = 0.9100, ROC-AUC = 0.9899
#   Fold 7: Accuracy = 0.8700, ROC-AUC = 0.9775
#   Fold 8: Accuracy = 0.8900, ROC-AUC = 0.9831
#   Fold 9: Accuracy = 0.8600, ROC-AUC = 0.9795
#   Fold 10: Accuracy = 0.8700, ROC-AUC = 0.9746
# Average Accuracy: 0.8890, Average ROC-AUC: 0.9831
#
#
# Training and evaluating with feature set: TF-IDF + LDA
#   Fold 1: Accuracy = 0.9100, ROC-AUC = 0.9841
#   Fold 2: Accuracy = 0.9200, ROC-AUC = 0.9914
#   Fold 3: Accuracy = 0.9800, ROC-AUC = 0.9985
#   Fold 4: Accuracy = 0.9700, ROC-AUC = 0.9939
#   Fold 5: Accuracy = 0.9300, ROC-AUC = 0.9844
#   Fold 6: Accuracy = 0.9000, ROC-AUC = 0.9942
#   Fold 7: Accuracy = 0.9400, ROC-AUC = 0.9955
#   Fold 8: Accuracy = 0.8800, ROC-AUC = 0.9909
#   Fold 9: Accuracy = 0.9300, ROC-AUC = 0.9955
#   Fold 10: Accuracy = 0.8800, ROC-AUC = 0.9850
# Average Accuracy: 0.9240, Average ROC-AUC: 0.9913
#
#
# Training and evaluating with feature set: BoW + N-grams
#   Fold 1: Accuracy = 0.9000, ROC-AUC = 0.9844
#   Fold 2: Accuracy = 0.9000, ROC-AUC = 0.9891
#   Fold 3: Accuracy = 0.9700, ROC-AUC = 0.9981
#   Fold 4: Accuracy = 0.9500, ROC-AUC = 0.9934
#   Fold 5: Accuracy = 0.9400, ROC-AUC = 0.9930
#   Fold 6: Accuracy = 0.9000, ROC-AUC = 0.9921
#   Fold 7: Accuracy = 0.9200, ROC-AUC = 0.9968
#   Fold 8: Accuracy = 0.9400, ROC-AUC = 0.9939
#   Fold 9: Accuracy = 0.9000, ROC-AUC = 0.9873
#   Fold 10: Accuracy = 0.9300, ROC-AUC = 0.9824
# Average Accuracy: 0.9250, Average ROC-AUC: 0.9910
#
#
# Training and evaluating with feature set: BoW + LDA
#   Fold 1: Accuracy = 0.8800, ROC-AUC = 0.9811
#   Fold 2: Accuracy = 0.9000, ROC-AUC = 0.9926
#   Fold 3: Accuracy = 0.9800, ROC-AUC = 0.9974
#   Fold 4: Accuracy = 0.9200, ROC-AUC = 0.9946
#   Fold 5: Accuracy = 0.9400, ROC-AUC = 0.9911
#   Fold 6: Accuracy = 0.9300, ROC-AUC = 0.9883
#   Fold 7: Accuracy = 0.9200, ROC-AUC = 0.9933
#   Fold 8: Accuracy = 0.9100, ROC-AUC = 0.9880
#   Fold 9: Accuracy = 0.9100, ROC-AUC = 0.9930
#   Fold 10: Accuracy = 0.9000, ROC-AUC = 0.9843
# Average Accuracy: 0.9190, Average ROC-AUC: 0.9904
#
#
# Training and evaluating with feature set: N-grams + LDA
#   Fold 1: Accuracy = 0.8700, ROC-AUC = 0.9806
#   Fold 2: Accuracy = 0.9000, ROC-AUC = 0.9785
#   Fold 3: Accuracy = 0.9500, ROC-AUC = 0.9970
#   Fold 4: Accuracy = 0.9100, ROC-AUC = 0.9809
#   Fold 5: Accuracy = 0.8900, ROC-AUC = 0.9886
#   Fold 6: Accuracy = 0.8900, ROC-AUC = 0.9865
#   Fold 7: Accuracy = 0.8600, ROC-AUC = 0.9855
#   Fold 8: Accuracy = 0.8800, ROC-AUC = 0.9788
#   Fold 9: Accuracy = 0.8800, ROC-AUC = 0.9825
#   Fold 10: Accuracy = 0.8400, ROC-AUC = 0.9682
# Average Accuracy: 0.8870, Average ROC-AUC: 0.9827
#
#
# Training and evaluating with feature set: TF-IDF + BoW + N-grams
#   Fold 1: Accuracy = 0.9000, ROC-AUC = 0.9817
#   Fold 2: Accuracy = 0.9200, ROC-AUC = 0.9925
#   Fold 3: Accuracy = 0.9600, ROC-AUC = 0.9982
#   Fold 4: Accuracy = 0.9700, ROC-AUC = 0.9944
#   Fold 5: Accuracy = 0.9300, ROC-AUC = 0.9939
#   Fold 6: Accuracy = 0.9200, ROC-AUC = 0.9896
#   Fold 7: Accuracy = 0.9500, ROC-AUC = 0.9954
#   Fold 8: Accuracy = 0.9300, ROC-AUC = 0.9926
#   Fold 9: Accuracy = 0.8900, ROC-AUC = 0.9910
#   Fold 10: Accuracy = 0.9000, ROC-AUC = 0.9814
# Average Accuracy: 0.9270, Average ROC-AUC: 0.9911
#
#
# Training and evaluating with feature set: TF-IDF + BoW + LDA
#   Fold 1: Accuracy = 0.8800, ROC-AUC = 0.9808
#   Fold 2: Accuracy = 0.9100, ROC-AUC = 0.9906
#   Fold 3: Accuracy = 0.9600, ROC-AUC = 0.9979
#   Fold 4: Accuracy = 0.9500, ROC-AUC = 0.9974
#   Fold 5: Accuracy = 0.9300, ROC-AUC = 0.9938
#   Fold 6: Accuracy = 0.9200, ROC-AUC = 0.9936
#   Fold 7: Accuracy = 0.9200, ROC-AUC = 0.9934
#   Fold 8: Accuracy = 0.9200, ROC-AUC = 0.9918
#   Fold 9: Accuracy = 0.9100, ROC-AUC = 0.9964
#   Fold 10: Accuracy = 0.8900, ROC-AUC = 0.9839
# Average Accuracy: 0.9190, Average ROC-AUC: 0.9919
#
#
# Training and evaluating with feature set: TF-IDF + N-grams + LDA
#   Fold 1: Accuracy = 0.8800, ROC-AUC = 0.9810
#   Fold 2: Accuracy = 0.9000, ROC-AUC = 0.9774
#   Fold 3: Accuracy = 0.9400, ROC-AUC = 0.9976
#   Fold 4: Accuracy = 0.9100, ROC-AUC = 0.9826
#   Fold 5: Accuracy = 0.9100, ROC-AUC = 0.9898
#   Fold 6: Accuracy = 0.9000, ROC-AUC = 0.9877
#   Fold 7: Accuracy = 0.8700, ROC-AUC = 0.9854
#   Fold 8: Accuracy = 0.8900, ROC-AUC = 0.9788
#   Fold 9: Accuracy = 0.8600, ROC-AUC = 0.9839
#   Fold 10: Accuracy = 0.8500, ROC-AUC = 0.9680
# Average Accuracy: 0.8910, Average ROC-AUC: 0.9832
#
#
# Training and evaluating with feature set: BoW + N-grams + LDA
#   Fold 1: Accuracy = 0.9100, ROC-AUC = 0.9836
#   Fold 2: Accuracy = 0.8800, ROC-AUC = 0.9886
#   Fold 3: Accuracy = 0.9800, ROC-AUC = 0.9975
#   Fold 4: Accuracy = 0.9300, ROC-AUC = 0.9911
#   Fold 5: Accuracy = 0.9400, ROC-AUC = 0.9951
#   Fold 6: Accuracy = 0.9100, ROC-AUC = 0.9843
#   Fold 7: Accuracy = 0.9200, ROC-AUC = 0.9960
#   Fold 8: Accuracy = 0.9400, ROC-AUC = 0.9932
#   Fold 9: Accuracy = 0.9100, ROC-AUC = 0.9928
#   Fold 10: Accuracy = 0.9300, ROC-AUC = 0.9799
# Average Accuracy: 0.9250, Average ROC-AUC: 0.9902
#
#
# Training and evaluating with feature set: All Combined
#   Fold 1: Accuracy = 0.9000, ROC-AUC = 0.9831
#   Fold 2: Accuracy = 0.9200, ROC-AUC = 0.9883
#   Fold 3: Accuracy = 0.9800, ROC-AUC = 0.9979
#   Fold 4: Accuracy = 0.9500, ROC-AUC = 0.9970
#   Fold 5: Accuracy = 0.9500, ROC-AUC = 0.9923
#   Fold 6: Accuracy = 0.8900, ROC-AUC = 0.9899
#   Fold 7: Accuracy = 0.9200, ROC-AUC = 0.9982
#   Fold 8: Accuracy = 0.9300, ROC-AUC = 0.9929
#   Fold 9: Accuracy = 0.9100, ROC-AUC = 0.9925
#   Fold 10: Accuracy = 0.9100, ROC-AUC = 0.9817
# Average Accuracy: 0.9260, Average ROC-AUC: 0.9914
#
#
# Summary of Results:
# Feature Set                    Accuracy   ROC-AUC
# TF-IDF                         0.9290     0.9942
# BoW                            0.9210     0.9902
# N-grams                        0.8920     0.9839
# LDA                            0.4240     0.7405
# TF-IDF + BoW                   0.9230     0.9908
# TF-IDF + N-grams               0.8890     0.9831
# TF-IDF + LDA                   0.9240     0.9913
# BoW + N-grams                  0.9250     0.9910
# BoW + LDA                      0.9190     0.9904
# N-grams + LDA                  0.8870     0.9827
# TF-IDF + BoW + N-grams         0.9270     0.9911
# TF-IDF + BoW + LDA             0.9190     0.9919
# TF-IDF + N-grams + LDA         0.8910     0.9832
# BoW + N-grams + LDA            0.9250     0.9902
# All Combined                   0.9260     0.9914
#
# === Best Feature Set ===
# Feature Set: TF-IDF
# Accuracy: 0.9290
# ROC-AUC: 0.9942
