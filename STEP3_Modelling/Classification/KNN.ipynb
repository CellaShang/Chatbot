# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from sklearn.metrics import (confusion_matrix, classification_report,
                             roc_auc_score, roc_curve, auc)
from sklearn.preprocessing import label_binarize
from itertools import cycle
#  from scipy import interp

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score
import numpy as np

# %%
DPPpath = '/content/drive/My Drive/Colab/AS4/STEP2-feature_Engineering/'
# Load preprocessed features
df_tfidf = pd.read_pickle(DPPpath + 'features_tfidf.pkl')
df_bow = pd.read_pickle(DPPpath + 'features_bow.pkl')
df_ngram = pd.read_pickle(DPPpath + 'features_ngram2.pkl')
df_lda = pd.read_pickle(DPPpath + 'features_lda.pkl')

# Prepare data
labels = df_tfidf['label']
numeric_labels = df_tfidf['label_num'].values
classes = np.unique(numeric_labels)
from sklearn.preprocessing import label_binarize
y_binarized = label_binarize(numeric_labels, classes=classes)

# Feature matrices (drop label columns)
X_tfidf = df_tfidf.drop(['label', 'label_num'], axis=1).values
X_bow = df_bow.drop(['label', 'label_num'], axis=1).values
X_ngram = df_ngram.drop(['label', 'label_num'], axis=1).values
X_lda = df_lda.drop(['label', 'label_num'], axis=1).values

# Combine features function
def combine_features(*arrays):
    return np.hstack(arrays)

# %%
# Dictionary of feature sets (include individual and combinations)
feature_sets = {
    'TF-IDF': X_tfidf,
    'BoW': X_bow,
    'N-grams': X_ngram,
    'LDA': X_lda,
    'TF-IDF + BoW': combine_features(X_tfidf, X_bow),
    'TF-IDF + N-grams': combine_features(X_tfidf, X_ngram),
    'TF-IDF + LDA': combine_features(X_tfidf, X_lda),
    'BoW + N-grams': combine_features(X_bow, X_ngram),
    'BoW + LDA': combine_features(X_bow, X_lda),
    'N-grams + LDA': combine_features(X_ngram, X_lda),
    'TF-IDF + BoW + N-grams': combine_features(X_tfidf, X_bow, X_ngram),
    'TF-IDF + BoW + LDA': combine_features(X_tfidf, X_bow, X_lda),
    'TF-IDF + N-grams + LDA': combine_features(X_tfidf, X_ngram, X_lda),
    'BoW + N-grams + LDA': combine_features(X_bow, X_ngram, X_lda),
    'All Combined': combine_features(X_tfidf, X_bow, X_ngram, X_lda),
}
y = labels

# %%
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
results = {}

for name, X in feature_sets.items():
    accuracies = []
    roc_aucs = []

    print(f"\nTraining and evaluating with feature set: {name}")
    for fold, (train_index, test_index) in enumerate(kf.split(X, numeric_labels), 1):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = numeric_labels[train_index], numeric_labels[test_index]
        y_test_binarized = y_binarized[test_index]

        params = {'metric': 'cosine', 'n_neighbors': 11, 'p': 1, 'weights': 'uniform'}

        fin_knn = KNeighborsClassifier(**params)
        fin_knn.fit(X_train, y_train)


        y_pred = fin_knn.predict(X_test)
        y_proba = fin_knn.predict_proba(X_test)

        acc = accuracy_score(y_test, y_pred)

        # Handle binary/multiclass ROC-AUC
        if len(np.unique(numeric_labels)) == 2:
            roc_auc = roc_auc_score(y_test, y_proba[:, 1])
        else:
            roc_auc = roc_auc_score(y_test_binarized, y_proba, multi_class='ovr')

        accuracies.append(acc)
        roc_aucs.append(roc_auc)

        print(f"  Fold {fold}: Accuracy = {acc:.4f}, ROC-AUC = {roc_auc:.4f}")

    avg_acc = np.mean(accuracies)
    avg_roc = np.mean(roc_aucs)
    results[name] = (avg_acc, avg_roc)

    print(f"Average Accuracy: {avg_acc:.4f}, Average ROC-AUC: {avg_roc:.4f}\n")

# Summary Table
print("\nSummary of Results:")
print(f"{'Feature Set':<30} {'Accuracy':<10} {'ROC-AUC':<10}")
for key, (acc, roc) in results.items():
    print(f"{key:<30} {acc:<10.4f} {roc:<10.4f}")

# Best Feature Set
best_feature_set = max(results.items(), key=lambda x: x[1][0])
best_name, (best_acc, best_roc) = best_feature_set

print("\n=== Best Feature Set ===")
print(f"Feature Set: {best_name}")
print(f"Accuracy: {best_acc:.4f}")
print(f"ROC-AUC: {best_roc:.4f}")
# Out:
# Training and evaluating with feature set: TF-IDF
#   Fold 1: Accuracy = 0.8400, ROC-AUC = 0.9752
#   Fold 2: Accuracy = 0.8300, ROC-AUC = 0.9841
#   Fold 3: Accuracy = 0.8900, ROC-AUC = 0.9868
#   Fold 4: Accuracy = 0.8700, ROC-AUC = 0.9767
#   Fold 5: Accuracy = 0.8900, ROC-AUC = 0.9833
#   Fold 6: Accuracy = 0.8200, ROC-AUC = 0.9839
#   Fold 7: Accuracy = 0.8000, ROC-AUC = 0.9759
#   Fold 8: Accuracy = 0.8300, ROC-AUC = 0.9656
#   Fold 9: Accuracy = 0.8300, ROC-AUC = 0.9756
#   Fold 10: Accuracy = 0.8200, ROC-AUC = 0.9727
# Average Accuracy: 0.8420, Average ROC-AUC: 0.9780
#
#
# Training and evaluating with feature set: BoW
#   Fold 1: Accuracy = 0.7600, ROC-AUC = 0.9228
#   Fold 2: Accuracy = 0.7800, ROC-AUC = 0.9542
#   Fold 3: Accuracy = 0.9100, ROC-AUC = 0.9748
#   Fold 4: Accuracy = 0.7300, ROC-AUC = 0.9185
#   Fold 5: Accuracy = 0.7500, ROC-AUC = 0.9420
#   Fold 6: Accuracy = 0.7800, ROC-AUC = 0.9464
#   Fold 7: Accuracy = 0.8100, ROC-AUC = 0.9690
#   Fold 8: Accuracy = 0.7300, ROC-AUC = 0.9271
#   Fold 9: Accuracy = 0.7100, ROC-AUC = 0.9261
#   Fold 10: Accuracy = 0.7200, ROC-AUC = 0.9314
# Average Accuracy: 0.7680, Average ROC-AUC: 0.9412
#
#
# Training and evaluating with feature set: N-grams
#   Fold 1: Accuracy = 0.7000, ROC-AUC = 0.9352
#   Fold 2: Accuracy = 0.7000, ROC-AUC = 0.9382
#   Fold 3: Accuracy = 0.7200, ROC-AUC = 0.9423
#   Fold 4: Accuracy = 0.7100, ROC-AUC = 0.9081
#   Fold 5: Accuracy = 0.7100, ROC-AUC = 0.9263
#   Fold 6: Accuracy = 0.7200, ROC-AUC = 0.9486
#   Fold 7: Accuracy = 0.7100, ROC-AUC = 0.9281
#   Fold 8: Accuracy = 0.7100, ROC-AUC = 0.9172
#   Fold 9: Accuracy = 0.6900, ROC-AUC = 0.9102
#   Fold 10: Accuracy = 0.7100, ROC-AUC = 0.9330
# Average Accuracy: 0.7080, Average ROC-AUC: 0.9287
#
#
# Training and evaluating with feature set: LDA
#   Fold 1: Accuracy = 0.3600, ROC-AUC = 0.7187
#   Fold 2: Accuracy = 0.4200, ROC-AUC = 0.7215
#   Fold 3: Accuracy = 0.4000, ROC-AUC = 0.7526
#   Fold 4: Accuracy = 0.3600, ROC-AUC = 0.6995
#   Fold 5: Accuracy = 0.3800, ROC-AUC = 0.7049
#   Fold 6: Accuracy = 0.4000, ROC-AUC = 0.7294
#   Fold 7: Accuracy = 0.5200, ROC-AUC = 0.7825
#   Fold 8: Accuracy = 0.3800, ROC-AUC = 0.6629
#   Fold 9: Accuracy = 0.4200, ROC-AUC = 0.7682
#   Fold 10: Accuracy = 0.4100, ROC-AUC = 0.7126
# Average Accuracy: 0.4050, Average ROC-AUC: 0.7253
#
#
# Training and evaluating with feature set: TF-IDF + BoW
#   Fold 1: Accuracy = 0.7600, ROC-AUC = 0.9226
#   Fold 2: Accuracy = 0.7800, ROC-AUC = 0.9538
#   Fold 3: Accuracy = 0.9000, ROC-AUC = 0.9739
#   Fold 4: Accuracy = 0.7300, ROC-AUC = 0.9184
#   Fold 5: Accuracy = 0.7500, ROC-AUC = 0.9426
#   Fold 6: Accuracy = 0.7900, ROC-AUC = 0.9469
#   Fold 7: Accuracy = 0.8200, ROC-AUC = 0.9681
#   Fold 8: Accuracy = 0.7400, ROC-AUC = 0.9277
#   Fold 9: Accuracy = 0.7100, ROC-AUC = 0.9237
#   Fold 10: Accuracy = 0.7200, ROC-AUC = 0.9314
# Average Accuracy: 0.7700, Average ROC-AUC: 0.9409
#
#
# Training and evaluating with feature set: TF-IDF + N-grams
#   Fold 1: Accuracy = 0.7000, ROC-AUC = 0.9358
#   Fold 2: Accuracy = 0.7100, ROC-AUC = 0.9364
#   Fold 3: Accuracy = 0.7300, ROC-AUC = 0.9464
#   Fold 4: Accuracy = 0.7100, ROC-AUC = 0.9090
#   Fold 5: Accuracy = 0.7100, ROC-AUC = 0.9346
#   Fold 6: Accuracy = 0.7500, ROC-AUC = 0.9531
#   Fold 7: Accuracy = 0.7300, ROC-AUC = 0.9317
#   Fold 8: Accuracy = 0.7300, ROC-AUC = 0.9191
#   Fold 9: Accuracy = 0.7200, ROC-AUC = 0.9134
#   Fold 10: Accuracy = 0.7200, ROC-AUC = 0.9327
# Average Accuracy: 0.7210, Average ROC-AUC: 0.9312
#
#
# Training and evaluating with feature set: TF-IDF + LDA
#   Fold 1: Accuracy = 0.7000, ROC-AUC = 0.9418
#   Fold 2: Accuracy = 0.7600, ROC-AUC = 0.9529
#   Fold 3: Accuracy = 0.8200, ROC-AUC = 0.9710
#   Fold 4: Accuracy = 0.7200, ROC-AUC = 0.9584
#   Fold 5: Accuracy = 0.7500, ROC-AUC = 0.9399
#   Fold 6: Accuracy = 0.7200, ROC-AUC = 0.9521
#   Fold 7: Accuracy = 0.7500, ROC-AUC = 0.9627
#   Fold 8: Accuracy = 0.7400, ROC-AUC = 0.9319
#   Fold 9: Accuracy = 0.7400, ROC-AUC = 0.9366
#   Fold 10: Accuracy = 0.7300, ROC-AUC = 0.9387
# Average Accuracy: 0.7430, Average ROC-AUC: 0.9486
#
#
# Training and evaluating with feature set: BoW + N-grams
#   Fold 1: Accuracy = 0.7800, ROC-AUC = 0.9290
#   Fold 2: Accuracy = 0.7700, ROC-AUC = 0.9506
#   Fold 3: Accuracy = 0.8700, ROC-AUC = 0.9699
#   Fold 4: Accuracy = 0.7600, ROC-AUC = 0.9198
#   Fold 5: Accuracy = 0.7300, ROC-AUC = 0.9453
#   Fold 6: Accuracy = 0.7900, ROC-AUC = 0.9395
#   Fold 7: Accuracy = 0.8100, ROC-AUC = 0.9607
#   Fold 8: Accuracy = 0.7300, ROC-AUC = 0.9186
#   Fold 9: Accuracy = 0.7200, ROC-AUC = 0.9295
#   Fold 10: Accuracy = 0.7500, ROC-AUC = 0.9427
# Average Accuracy: 0.7710, Average ROC-AUC: 0.9406
#
#
# Training and evaluating with feature set: BoW + LDA
#   Fold 1: Accuracy = 0.7500, ROC-AUC = 0.9247
#   Fold 2: Accuracy = 0.7800, ROC-AUC = 0.9572
#   Fold 3: Accuracy = 0.9000, ROC-AUC = 0.9699
#   Fold 4: Accuracy = 0.7200, ROC-AUC = 0.9189
#   Fold 5: Accuracy = 0.7500, ROC-AUC = 0.9438
#   Fold 6: Accuracy = 0.7800, ROC-AUC = 0.9470
#   Fold 7: Accuracy = 0.8100, ROC-AUC = 0.9663
#   Fold 8: Accuracy = 0.7400, ROC-AUC = 0.9276
#   Fold 9: Accuracy = 0.7200, ROC-AUC = 0.9233
#   Fold 10: Accuracy = 0.7300, ROC-AUC = 0.9379
# Average Accuracy: 0.7680, Average ROC-AUC: 0.9417
#
#
# Training and evaluating with feature set: N-grams + LDA
#   Fold 1: Accuracy = 0.7000, ROC-AUC = 0.9338
#   Fold 2: Accuracy = 0.7200, ROC-AUC = 0.9390
#   Fold 3: Accuracy = 0.7400, ROC-AUC = 0.9511
#   Fold 4: Accuracy = 0.7300, ROC-AUC = 0.9111
#   Fold 5: Accuracy = 0.7000, ROC-AUC = 0.9329
#   Fold 6: Accuracy = 0.7300, ROC-AUC = 0.9480
#   Fold 7: Accuracy = 0.7100, ROC-AUC = 0.9313
#   Fold 8: Accuracy = 0.7000, ROC-AUC = 0.9187
#   Fold 9: Accuracy = 0.7200, ROC-AUC = 0.9141
#   Fold 10: Accuracy = 0.7300, ROC-AUC = 0.9351
# Average Accuracy: 0.7180, Average ROC-AUC: 0.9315
#
#
# Training and evaluating with feature set: TF-IDF + BoW + N-grams
#   Fold 1: Accuracy = 0.7800, ROC-AUC = 0.9300
#   Fold 2: Accuracy = 0.7700, ROC-AUC = 0.9507
#   Fold 3: Accuracy = 0.8700, ROC-AUC = 0.9698
#   Fold 4: Accuracy = 0.7700, ROC-AUC = 0.9224
#   Fold 5: Accuracy = 0.7400, ROC-AUC = 0.9459
#   Fold 6: Accuracy = 0.7900, ROC-AUC = 0.9394
#   Fold 7: Accuracy = 0.8100, ROC-AUC = 0.9607
#   Fold 8: Accuracy = 0.7400, ROC-AUC = 0.9192
#   Fold 9: Accuracy = 0.7400, ROC-AUC = 0.9297
#   Fold 10: Accuracy = 0.7500, ROC-AUC = 0.9429
# Average Accuracy: 0.7760, Average ROC-AUC: 0.9411
#
#
# Training and evaluating with feature set: TF-IDF + BoW + LDA
#   Fold 1: Accuracy = 0.7600, ROC-AUC = 0.9248
#   Fold 2: Accuracy = 0.7800, ROC-AUC = 0.9570
#   Fold 3: Accuracy = 0.9000, ROC-AUC = 0.9700
#   Fold 4: Accuracy = 0.7200, ROC-AUC = 0.9190
#   Fold 5: Accuracy = 0.7500, ROC-AUC = 0.9410
#   Fold 6: Accuracy = 0.7800, ROC-AUC = 0.9476
#   Fold 7: Accuracy = 0.8100, ROC-AUC = 0.9701
#   Fold 8: Accuracy = 0.7400, ROC-AUC = 0.9276
#   Fold 9: Accuracy = 0.7200, ROC-AUC = 0.9238
#   Fold 10: Accuracy = 0.7300, ROC-AUC = 0.9380
# Average Accuracy: 0.7690, Average ROC-AUC: 0.9419
#
#
# Training and evaluating with feature set: TF-IDF + N-grams + LDA
#   Fold 1: Accuracy = 0.6800, ROC-AUC = 0.9344
#   Fold 2: Accuracy = 0.7200, ROC-AUC = 0.9374
#   Fold 3: Accuracy = 0.7300, ROC-AUC = 0.9513
#   Fold 4: Accuracy = 0.7300, ROC-AUC = 0.9131
#   Fold 5: Accuracy = 0.7000, ROC-AUC = 0.9354
#   Fold 6: Accuracy = 0.7300, ROC-AUC = 0.9499
#   Fold 7: Accuracy = 0.7100, ROC-AUC = 0.9359
#   Fold 8: Accuracy = 0.7200, ROC-AUC = 0.9213
#   Fold 9: Accuracy = 0.7100, ROC-AUC = 0.9177
#   Fold 10: Accuracy = 0.7300, ROC-AUC = 0.9346
# Average Accuracy: 0.7160, Average ROC-AUC: 0.9331
#
#
# Training and evaluating with feature set: BoW + N-grams + LDA
#   Fold 1: Accuracy = 0.7800, ROC-AUC = 0.9316
#   Fold 2: Accuracy = 0.7700, ROC-AUC = 0.9537
#   Fold 3: Accuracy = 0.8700, ROC-AUC = 0.9700
#   Fold 4: Accuracy = 0.7600, ROC-AUC = 0.9251
#   Fold 5: Accuracy = 0.7400, ROC-AUC = 0.9492
#   Fold 6: Accuracy = 0.7900, ROC-AUC = 0.9429
#   Fold 7: Accuracy = 0.8100, ROC-AUC = 0.9610
#   Fold 8: Accuracy = 0.7300, ROC-AUC = 0.9198
#   Fold 9: Accuracy = 0.7400, ROC-AUC = 0.9314
#   Fold 10: Accuracy = 0.7400, ROC-AUC = 0.9430
# Average Accuracy: 0.7730, Average ROC-AUC: 0.9428
#
#
# Training and evaluating with feature set: All Combined
#   Fold 1: Accuracy = 0.7800, ROC-AUC = 0.9321
#   Fold 2: Accuracy = 0.7700, ROC-AUC = 0.9539
#   Fold 3: Accuracy = 0.8700, ROC-AUC = 0.9701
#   Fold 4: Accuracy = 0.7600, ROC-AUC = 0.9252
#   Fold 5: Accuracy = 0.7400, ROC-AUC = 0.9492
#   Fold 6: Accuracy = 0.7900, ROC-AUC = 0.9429
#   Fold 7: Accuracy = 0.8100, ROC-AUC = 0.9610
#   Fold 8: Accuracy = 0.7300, ROC-AUC = 0.9198
#   Fold 9: Accuracy = 0.7400, ROC-AUC = 0.9316
#   Fold 10: Accuracy = 0.7400, ROC-AUC = 0.9426
# Average Accuracy: 0.7730, Average ROC-AUC: 0.9429
#
#
# Summary of Results:
# Feature Set                    Accuracy   ROC-AUC
# TF-IDF                         0.8420     0.9780
# BoW                            0.7680     0.9412
# N-grams                        0.7080     0.9287
# LDA                            0.4050     0.7253
# TF-IDF + BoW                   0.7700     0.9409
# TF-IDF + N-grams               0.7210     0.9312
# TF-IDF + LDA                   0.7430     0.9486
# BoW + N-grams                  0.7710     0.9406
# BoW + LDA                      0.7680     0.9417
# N-grams + LDA                  0.7180     0.9315
# TF-IDF + BoW + N-grams         0.7760     0.9411
# TF-IDF + BoW + LDA             0.7690     0.9419
# TF-IDF + N-grams + LDA         0.7160     0.9331
# BoW + N-grams + LDA            0.7730     0.9428
# All Combined                   0.7730     0.9429
#
# === Best Feature Set ===
# Feature Set: TF-IDF
# Accuracy: 0.8420
# ROC-AUC: 0.9780
